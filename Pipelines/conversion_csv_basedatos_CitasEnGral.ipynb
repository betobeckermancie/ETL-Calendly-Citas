# %%
# Crear la base de datos en caso de que no exista
spark.sql("CREATE DATABASE IF NOT EXISTS db_citas")

# Eliminar la tabla si ya existe
spark.sql("DROP TABLE IF EXISTS db_citas.citas_gral")

# Leer el archivo CSV/
df = spark.read.csv("/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv", header=True, inferSchema=True)

# Escribir el DataFrame como una nueva tabla
df.write.mode("overwrite").saveAsTable("db_citas.citas_gral")

# Verificar que la tabla se haya creado
spark.sql("SHOW TABLES IN db_citas").show()
# Out:
# +--------+----------+-----------+
# |database| tableName|isTemporary|
# +--------+----------+-----------+
# |db_citas|citas_gral|      false|
# +--------+----------+-----------+

# %%
# %sql
SELECT * FROM db_citas.citas_gral
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cliente</th><th>medio</th><th>anuncio</th><th>fecha_cita</th><th>hora_cita</th><th>fraccionamiento</th><th>asesor</th><th>contacto_cliente</th></tr></thead><tbody><tr><td>Anahí_Carreón</td><td>facebook</td><td>null</td><td>2024-03-29</td><td>2024-11-28T11:00:00Z</td><td>altavista</td><td>evelyn</td><td>8444990294</td></tr><tr><td>Oscar_Leonardo_Domínguez</td><td>pagina_web</td><td>null</td><td>2024-03-31</td><td>2024-11-28T12:00:00Z</td><td>morillo</td><td>elbia</td><td>8443490772</td></tr><tr><td>Jorge_Antonio_Carmona</td><td>whatsapp</td><td>null</td><td>2024-03-31</td><td>2024-11-28T11:00:00Z</td><td>bosques</td><td>miguel</td><td>7224435137</td></tr><tr><td>Gabriela_González</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>2024-11-28T04:00:00Z</td><td>altavista</td><td>miguel</td><td>8441011388</td></tr><tr><td>Jose_Negrete</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>2024-11-28T03:00:00Z</td><td>altavista</td><td>miguel</td><td>8441053934</td></tr><tr><td>Oscar_Alan_Piña</td><td>pagina_web</td><td>null</td><td>2024-04-01</td><td>2024-11-28T05:00:00Z</td><td>morillo</td><td>cesar</td><td>3411703104</td></tr><tr><td>Jonathan_Jovany_Garibay_Acevedo</td><td>pagina_web</td><td>null</td><td>2024-04-01</td><td>2024-11-28T11:00:00Z</td><td>altavista</td><td>evelyn</td><td>8444990294</td></tr><tr><td>Víctor_Martínez</td><td>facebook</td><td>null</td><td>2024-04-03</td><td>2024-11-28T02:00:00Z</td><td>altavista</td><td>evelyn</td><td>8441224454</td></tr><tr><td>Manuel_Alcalá_Fernandez</td><td>facebook</td><td>null</td><td>2024-04-03</td><td>2024-11-28T11:00:00Z</td><td>altavista</td><td>evelyn</td><