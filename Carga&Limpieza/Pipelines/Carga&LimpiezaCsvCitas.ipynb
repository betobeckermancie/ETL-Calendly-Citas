# %% [markdown]
# ## Instalar las librerias necesarias para hacer el manejo

# %%
# %pip install gspread google-auth
# %pip install gspread oauth2client
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting gspread
#   Downloading gspread-6.1.4-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.9 MB/s eta 0:00:00
# Collecting google-auth
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 kB 10.5 MB/s eta 0:00:00
# Collecting google-auth-oauthlib>=0.4.1
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 18.9 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.0)
# Requirement already satisfied: requests>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Installing collected packages: pyasn1, cachetools, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, gspread
# Successfully installed cachetools-5.5.0 google-auth-2.36.0 google-auth-oauthlib-1.2.1 gspread-6.1.4 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: gspread in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (6.1.4)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from gspread) (1.2.1)
# Requirement already satisfied: google-auth>=1.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from gspread) (2.36.0)
# Requirement already satisfied: six>=1.6.1 in /usr/lib/python3/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from oauth2client) (4.9)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-dc4698f2-fb92-499d-896b-30a1575f0d11/lib/python3.10/site-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /databricks/python3/lib/python3.10/site-packages (from httplib2>=0.9.1->oauth2client) (3.0.9)
# Requirement already satisfied: requests>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.28.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2022.12.7)
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ## reiniciar las librerias para poder usarlas (siempre se tiene que hacer)

# %%
dbutils.library.restartPython()

# %% [markdown]
# ## coneccion con el archivo en especifico para extraer el sheet(archivo) y worksheet(hojas dentro del archivo)

# %%
import gspread
from google.oauth2.service_account import Credentials
import pandas as pd
import os

# Configuración de credenciales
scopes = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]

# Ruta al archivo de credenciales JSON en DBFS
json_creds_path = "/dbfs/mnt/GoogleSheets/Credenciales/GoogleSheets_Credenciales.json"

# Cargar las credenciales con el alcance definido
creds = Credentials.from_service_account_file(json_creds_path, scopes=scopes)
client = gspread.authorize(creds)

# Introducir el ID del Google Sheet
sheet_id = "1ba6l4dFTroMgKk-zqI-jMBSEY4ZMgDJe7m3JrrtKXLE"  # Aquí debes colocar el ID de tu hoja, ejemplo: "1dBFzUMXbEMDSPuoyDOi6L2gGnD-fnK1dNt4h8ei_H0"

# Ruta base donde se guardarán los archivos CSV
base_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Crear el directorio si no existe
if not os.path.exists(base_path):
    os.makedirs(base_path)
    print(f"Directorio creado: {base_path}")
else:
    print(f"Directorio ya existente: {base_path}")

# Conexión al Google Sheet por ID
try:
    spreadsheet = client.open_by_key(sheet_id)
    print(f"Conexión exitosa al documento: {spreadsheet.title}")
    
    # Descargar todas las hojas (worksheets) existentes
    worksheets = spreadsheet.worksheets()
    print("Hojas de cálculo disponibles:")
    for sheet in worksheets:
        print(f"- {sheet.title}")
        # Descargar todos los registros de la hoja
        data = sheet.get_all_records()  # Descarga los datos como una lista de diccionarios
        df = pd.DataFrame(data)  # Convertir los datos a un DataFrame de pandas
        print(f"\nDatos de la hoja '{sheet.title}':")
        print(df.head())  # Mostrar las primeras filas para confirmar

        # Guardar cada hoja como archivo CSV en DBFS
        file_path = os.path.join(base_path, f"{sheet.title}.csv")
        df.to_csv(file_path, index=False)
        print(f"Datos de la hoja '{sheet.title}' guardados en: {file_path}")

except Exception as e:
    print(f"Error al conectar o procesar las hojas de cálculo: {e}")
# Out:
# Directorio ya existente: /dbfs/mnt/GoogleSheets/CSV's_Descargados/
# Conexión exitosa al documento: Base_Datos_Citas_Analisis(beto)
# Hojas de cálculo disponibles:
# - CitasGral
#
# Datos de la hoja 'CitasGral':
#              Nombre    Medio  ... Asesor     Telefono
# 0  Griselda Rosales  Pag web  ...          8441842531
# 1    Alejandra Rios  llamada  ...         84434995585
# 2         Monserrat    whats  ...         84434995585
# 3     Israel Roman     whats  ...          8711748161
# 4  Alejandro Montes    whats  ...          8443534814
#
# [5 rows x 8 columns]
# Datos de la hoja 'CitasGral' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv
# - Mayo_2023
#
# Datos de la hoja 'Mayo_2023':
#                     Nombre    Medio  ...  asesor      Telefono landings
# 0            Carlos García     face  ...   Cesar    8120066732       no
# 1              Yesica Soto     face  ...   Cesar   28445343568       no
# 2             Diana Barron     face  ...   Elbia  871 127 2172       no
# 3             Javier Perez  llamada  ...  Sahira    7291055330       no
# 4    Paola Daniela Acevedo  Pag web  ...   Cesar  844 350 3113       no
#
# [5 rows x 11 columns]
# Datos de la hoja 'Mayo_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv
# - Junio_2023
#
# Datos de la hoja 'Junio_2023':
#                       Nombre       Medio  ...    Telefono landings
# 0              Natalia López    facebook  ...  8446106506       no
# 1                 Mónica hdz  pagina web  ...  8443068667       no
# 2                 Juan Loera     llamada  ...  8446106506       no
# 3            Reyna Ruvalcaba    whatsapp  ...  8441319607       no
# 4  Juan Manuel Jimenez Roman    facebook  ...  8444611714       no
#
# [5 rows x 10 columns]
# Datos de la hoja 'Junio_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv
# - Julio_2023
#
# Datos de la hoja 'Julio_2023':
#                           Nombre       Medio  ... asesor    Telefono landings
# 0                Reyna Hernández    Facebook  ...  Diego  9131020783
# 1                   Jesús Acosta    Facebook  ...  Elbia  8445611725
# 2                        Geovani  Pagina web  ...  Reyna  8442162451
# 3    Marin Livay Castillo García  Pagina web  ...  Reyna  8443006079
# 4                    Luis David   Pagina web  ...  Diego  9987434155
#
# [5 rows x 11 columns]
# Datos de la hoja 'Julio_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv
# - Agosto_2023
#
# Datos de la hoja 'Agosto_2023':
#                               Nombre       Medio  ... asesor    Telefono landings
# 0    Mario Humberto Rodríguez Cortes  pagina web  ...  Elbia  8443310524
# 1                          Liz Casas  pagina web  ...  Reyna  8442811244
# 2                     Ulises Morales  pagina web  ...  Diego  8442088488
# 3                  Asael Villanueva   pagina web  ...  Reyna  8441967828
# 4                  Mariana Rodríguez    Facebook  ...  Cesar  8441316156
#
# [5 rows x 11 columns]
# Datos de la hoja 'Agosto_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv
# - Septiembre_2023
#
# Datos de la hoja 'Septiembre_2023':
#               Nombre       Medio Ad  ... Fraccionamiento asesor    Telefono landings
# 0      Sofia Cordova    Facebook     ...       Altavista  Elbia  8443836672
# 1        Roger David    Facebook     ...       Altavista  Elbia  8448807009
# 2      Eduardo Cerda    Facebook     ...         Morillo  Elbia  8441570596
# 3    Erika L Rosales    Facebook     ...       Altavista  Diego  8443931653
# 4       Dana Cabello  Pagina web     ...       Altavista  Reyna  8441862621
#
# [5 rows x 11 columns]
# Datos de la hoja 'Septiembre_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv
# - Octubre_2023
#
# Datos de la hoja 'Octubre_2023':
#                                Nombre       Medio  ... asesor    Telefono landings
# 0    Roberto Alejandro Ramírez Galván  pagina web  ...  Elbia  8445358498
# 1                        Perla Ibarra    facebook  ...  Elbia  8441755394
# 2                José Andrés Martínez  pagina web  ...  Reyna  8661012143
# 3                      David Martinez    facebook  ...  Laura  8443811597
# 4                      Araceny Castro    facebook  ...  Laura  8446656411
#
# [5 rows x 11 columns]
# Datos de la hoja 'Octubre_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv
# - Noviembre_2023
#
# Datos de la hoja 'Noviembre_2023':
#                       Nombre     Medio  ... asesor    Telefono landings
# 0    Isidro Aguilar Martínez  facebook  ...  Elbia  8442752108
# 1        Luz Gabriela Garcia  facebook  ...  Laura  8442946290
# 2     Esmeralda García Orzua  whatsapp  ...  Reyna  8445874407
# 3                Laura Parra  facebook  ...  Laura  8442868903
# 4               Erick Mújica  facebook  ...  Reyna  8441395458
#
# [5 rows x 11 columns]
# Datos de la hoja 'Noviembre_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv
# - Diciembre_2023
#
# Datos de la hoja 'Diciembre_2023':
#                              Nombre  ... asesor    Telefono
# 0                              Iván  ...  Laura  8448707966
# 1                            Adrián  ...  Laura  8441959583
# 2                  Rogelio Castillo  ...  Laura  8441078794
# 3                    Fermin Estrada  ...  Cesar  8713917727
# 4    Lesly Brisvane Torres Cisneros  ...  Laura  8715475195
#
# [5 rows x 10 columns]
# Datos de la hoja 'Diciembre_2023' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv
# - Enero_2024
#
# Datos de la hoja 'Enero_2024':
#                 Nombre       Medio Ad  ...   Hora Fraccionamiento asesor    Telefono
# 0    Estrella Esquivel     tik tok     ...  12:00         Morillo  Reyna  8446777595
# 1        Laura Obregón    whatsapp     ...   5:00         Morillo  Reyna  8446095369
# 2       Erika Martínez    facebook     ...   6:00       Altavista  Reyna  8448801442
# 3         Laura Tovar     facebook     ...   6:00         Morillo  Reyna  8787915290
# 4      Patricia Macías  pagina web     ...  11:00         Morillo  Elbia  8442767676
#
# [5 rows x 10 columns]
# Datos de la hoja 'Enero_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv
# - Febrero_2024
#
# Datos de la hoja 'Febrero_2024':
#                       Nombre       Medio  ... Fraccionamiento asesor    Telefono
# 0            Adriana Cardona    facebook  ...         Morillo  Reyna  8446680100
# 1       Rosa Argelia Arriaga    facebook  ...         Morillo  Elbia  8441607260
# 2        Esteban H. Martínez    facebook  ...         Morillo  Elbia  8421154533
# 3            Angel contreras  pagina web  ...         Morillo  Cesar  8442403918
# 4    Alejandro Elías Badillo     llamada  ...       Altavista  Cesar  8443409063
#
# [5 rows x 10 columns]
# Datos de la hoja 'Febrero_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv
# - Marzo_2024
#
# Datos de la hoja 'Marzo_2024':
#                         Nombre       Medio  ... Fraccionamiento  asesor    Telefono
# 0         Antonio Lucio Bernal    facebook  ...       Altavista   Elbia  8444601360
# 1            Ana Lucia Reynaga  pagina web  ...       Altavista   Elbia  8443474635
# 2                Eunice Garcia  pagina web  ...           Rocal  Miguel  8442819078
# 3            Evangelina Zúñiga    facebook  ...       Altavista   Elbia  8445416763
# 4    Carlos Alfredo Mtz Aguayo  pagina web  ...       Altavista   Cesar  8442788104
#
# [5 rows x 10 columns]
# Datos de la hoja 'Marzo_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv
# - Abril_2024
#
# Datos de la hoja 'Abril_2024':
#                        Nombre       Medio  ... Fraccionamiento  asesor    Telefono
# 0               Anahí Carreón    facebook  ...       Altavista  Evelyn  8444990294
# 1    Oscar Leonardo Domínguez  pagina web  ...         Morillo   Elbia  8443490772
# 2       Jorge Antonio Carmona    whatsapp  ...         Bosques  Miguel  7224435137
# 3           Gabriela González    facebook  ...       Altavista  Miguel  8441011388
# 4               Jose Negrete     facebook  ...       Altavista  Miguel  8441053934
#
# [5 rows x 10 columns]
# Datos de la hoja 'Abril_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv
# - Mayo_2024
#
# Datos de la hoja 'Mayo_2024':
#                                    Nombre  ...  asesor    Telefono
# 0    Sergio Juan Francisco Castillo Cerda  ...  Evelyn  8445992312
# 1              Eduardo Alexis Rangel Lugo  ...  Evelyn  8442469432
# 2                       Francisco Pérez    ...  Evelyn  8441327319
# 3                  Mayra Vargas Hernández  ...  Miguel  8442112136
# 4                        Daniel Sepúlveda  ...  Miguel  8444195728
#
# [5 rows x 10 columns]
# Datos de la hoja 'Mayo_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv
# - Junio_2024
#
# Datos de la hoja 'Junio_2024':
#                                Nombre  ...  asesor    Telefono
# 0              Gonzalo Vallejo Quiroz  ...   Elbia  8446071027
# 1         Miguel ángel de león zapata  ...   Cesar  8442784468
# 2    Yadira elyzzette Ramírez Partida  ...   Elbia  8442279620
# 3              Erika Isabel Esmeralda  ...  Miguel  8180757930
# 4                     Mariana Amezcua  ...  Miguel  8446767703
#
# [5 rows x 10 columns]
# Datos de la hoja 'Junio_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv
# - Julio_2024
#
# Datos de la hoja 'Julio_2024':
#                           Nombre  ...  asesor    Telefono
# 0                    Félix López  ...    Luis  8441249781
# 1                    Cesar López  ...  Evelyn  9565265626
# 2                     Ramón Cruz  ...  Evelyn  8444928812
# 3    Luis Carlos Reyes Hernández  ...  Evelyn  8443818107
# 4                    Osiel Eguía  ...   Cesar  8442895007
#
# [5 rows x 10 columns]
# Datos de la hoja 'Julio_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv
# - Agosto_2024
#
# Datos de la hoja 'Agosto_2024':
#                           Nombre  ...  asesor    Telefono
# 0                   Rene Vázquez  ...    Luis  7291835308
# 1                    Jesús Cerda  ...   Cesar  8445422891
# 2                   Mayra Vargas  ...  Miguel  8443898593
# 3    Jose Daniel Cavazos Aguilar  ...   Cesar  8441399660
# 4               Zaira Sandoval\n  ...   Cesar  8448815118
#
# [5 rows x 10 columns]
# Datos de la hoja 'Agosto_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv
# - Septiembre_2024
#
# Datos de la hoja 'Septiembre_2024':
#                Nombre     Medio Ad  ...   Hora Fraccionamiento  asesor    Telefono
# 0             Aracely  facebook     ...  12:00         Morillo  Miguel  8445842935
# 1          Sergio faz  facebook     ...   1:00         Morillo  Miguel  8442931403
# 2    Adrián Rodríguez  facebook     ...   3:00         Morillo   Cesar  8441284722
# 3     Kenia de la Paz  facebook     ...   5:00       Altavista  Lupita  8444537425
# 4       César Méndez   facebook     ...   6:00         Morillo    Luis  8441382132
#
# [5 rows x 10 columns]
# Datos de la hoja 'Septiembre_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv
# - Octubre_2024
#
# Datos de la hoja 'Octubre_2024':
#                                   Nombre  ...   asesor    Telefono
# 0    Griselda Guadalupe Gonzalez Rosales  ...    Cesar  8442957068
# 1                                 Hector  ...   Lupita  8442785895
# 2        Epifanio Antonio Ortiz Espinoza  ...  Gabriel  8442019020
# 3            Marco Antonio Andrade Peña   ...  Gabriel  8446045311
# 4                           Adolfo Silva  ...   Lupita  7774179260
#
# [5 rows x 10 columns]
# Datos de la hoja 'Octubre_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv
# - Noviembre_2024
#
# Datos de la hoja 'Noviembre_2024':
#                      Nombre       Medio  ... Fraccionamiento   asesor    Telefono
# 0    María Corina Domínguez  pagina web  ...           Rocal     Luis  8441053370
# 1            Claudia Acosta    facebook  ...       Altavista  Gabriel  8443072342
# 2     Monica Orozco Narvaiz    facebook  ...       Altavista     Luis  8441856547
# 3           Violeta Herrera    facebook  ...         Morillo    Cesar  8442771657
# 4              Diana uresti    facebook  ...       Altavista    Cesar  2291461782
#
# [5 rows x 10 columns]
# Datos de la hoja 'Noviembre_2024' guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv

# %% [markdown]
# ### revisar que se extrajo en orden

# %%
display(dbutils.fs.ls("/mnt/GoogleSheets/CSV's_Descargados/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv</td><td>Abril_2024.csv</td><td>4293</td><td>1732820189000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv</td><td>Agosto_2023.csv</td><td>3483</td><td>1732820187000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv</td><td>Agosto_2024.csv</td><td>9023</td><td>1732820190000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv</td><td>CitasGral.csv</td><td>21985</td><td>1732820186000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv</td><td>Diciembre_2023.csv</td><td>2820</td><td>1732820188000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv</td><td>Enero_2024.csv</td><td>4602</td><td>1732820188000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv</td><td>Febrero_2024.csv</td><td>5273</td><td>1732820189000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv</td><td>Julio_2023.csv</td><td>4544</td><td>1732820187000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv</td><td>Julio_2024.csv</td><td>3965</td><td>1732820190000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv</td><td>Junio_2023.csv</td><td>6196</td><td>1732820187000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv</td><td>Junio_2024.csv</td><td>4091</td><td>1732820189000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv</td><td>Marzo_2024.csv</td><td>5247</td><td>1732820189000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv</td><td>Mayo_2023.csv</td><td>5828</td><td>1732820186000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv</td><td>Mayo_2024.csv</td><td>3499</td><td>1732820189000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv</td><td>Noviembre_2023.csv</td><td>4198</td><td>1732820188000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv</td><td>Noviembre_2024.csv</td><td>5718</td><td>1732820190000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv</td><td>Octubre_2023.csv</td><td>4192</td><td>1732820188000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv</td><td>Octubre_2024.csv</td><td>10093</td><td>1732820190000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv</td><td>Septiembre_2023.csv</td><td>4014</td><td>1732820187000</td></tr><tr><td>dbfs:/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv</td><td>Septiembre_2024.csv</td><td>10745</td><td>1732820190000</td></tr></tbody></table></div>

# %% [markdown]
# ##lee cuantos registros contiene cada archivo

# %%
import os
import pandas as pd

# Ruta de la carpeta donde están los archivos
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Inicializar contadores
total_records = 0
file_records = {}

# Recorrer todos los archivos en la carpeta
for file_name in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file_name)
    
    # Verificar si es un archivo (y no una carpeta)
    if os.path.isfile(file_path):
        try:
            # Procesar solo archivos CSV o TXT (puedes agregar más formatos si es necesario)
            if file_name.endswith(".csv"):
                # Leer el archivo CSV
                df = pd.read_csv(file_path)
                records = len(df)
                file_records[file_name] = records
                total_records += records
            elif file_name.endswith(".txt"):
                # Leer archivo de texto línea por línea
                with open(file_path, "r") as f:
                    records = sum(1 for line in f)
                file_records[file_name] = records
                total_records += records
        except Exception as e:
            print(f"Error procesando el archivo {file_name}: {e}")

# Mostrar los resultados
print("Cantidad de registros por archivo:")
for file, count in file_records.items():
    print(f"{file}: {count} registros")

print(f"\nCantidad total de registros en la carpeta: {total_records}")
# Out:
# Cantidad de registros por archivo:
# Abril_2024.csv: 53 registros
# Agosto_2023.csv: 41 registros
# Agosto_2024.csv: 111 registros
# CitasGral.csv: 281 registros
# Diciembre_2023.csv: 34 registros
# Enero_2024.csv: 56 registros
# Febrero_2024.csv: 64 registros
# Julio_2023.csv: 55 registros
# Julio_2024.csv: 49 registros
# Junio_2023.csv: 70 registros
# Junio_2024.csv: 50 registros
# Marzo_2024.csv: 65 registros
# Mayo_2023.csv: 62 registros
# Mayo_2024.csv: 43 registros
# Noviembre_2023.csv: 52 registros
# Noviembre_2024.csv: 70 registros
# Octubre_2023.csv: 50 registros
# Octubre_2024.csv: 125 registros
# Septiembre_2023.csv: 49 registros
# Septiembre_2024.csv: 137 registros
#
# Cantidad total de registros en la carpeta: 1517

# %% [markdown]
# ## eliminar columnas que no se necesitan

# %%
import pandas as pd
import os

# Ruta donde están los CSVs
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Iterar sobre los archivos en la carpeta
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # Verifica que sea un archivo CSV
        file_path = os.path.join(folder_path, file)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Filtrar las columnas eliminando las que se llamen 'Unnamed', 'landings' o 'Día'
        columns_to_remove = [col for col in df.columns if "Unnamed" in col or col in ["landings", "Día","dia"]]
        df = df.drop(columns=columns_to_remove, errors="ignore")
        
        # Sobrescribir el archivo original con el DataFrame limpio
        df.to_csv(file_path, index=False)
        print(f"Archivo limpiado y sobrescrito: {file_path}")

print("Proceso de limpieza completado.")
# Out:
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv
# Archivo limpiado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv
# Proceso de limpieza completado.

# %% [markdown]
# ## cambio de columnas a minusculas y sin acentos

# %%
import pandas as pd
import os
import unicodedata

# Ruta donde están los CSVs
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Función para eliminar acentos de los nombres de las columnas
def remove_accents(column_name):
    return ''.join(
        char for char in unicodedata.normalize('NFD', column_name)
        if unicodedata.category(char) != 'Mn'
    )

# Iterar sobre los archivos en la carpeta
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # Verifica que sea un archivo CSV
        file_path = os.path.join(folder_path, file)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Convertir columnas a minúsculas y eliminar acentos
        df.columns = [remove_accents(col.lower()) for col in df.columns]
        
        # Sobrescribir el archivo original con el DataFrame modificado
        df.to_csv(file_path, index=False)
        print(f"Archivo actualizado: {file_path}")

print("Proceso completado: columnas en minúsculas y sin acentos.")
# Out:
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv
# Archivo actualizado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv
# Proceso completado: columnas en minúsculas y sin acentos.

# %% [markdown]
# ## renombrar columnas de todos los archivos

# %%
import pandas as pd
import os

# Ruta donde están los CSVs
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Iterar sobre los archivos en la carpeta
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # Verifica que sea un archivo CSV
        file_path = os.path.join(folder_path, file)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Renombrar columnas según el mapeo
        df.rename(columns={
            "nombre": "cliente",
            "ad": "anuncio",
            "fecha": "fecha_cita",
            "hora": "hora_cita",
            "telefono": "contacto_cliente",
        }, inplace=True)
        
        # Guardar el archivo actualizado en el mismo lugar
        df.to_csv(file_path, index=False)
        print(f"Archivo procesado y guardado: {file_path}")

print("Renombrado de columnas completado.")
# Out:
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv
# Archivo procesado y guardado: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv
# Renombrado de columnas completado.

# %% [markdown]
# ## establecer tipos de columnas

# %%
import pandas as pd
import os

# Ruta donde están los CSVs
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Iterar sobre los archivos en la carpeta
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # Verifica que sea un archivo CSV
        file_path = os.path.join(folder_path, file)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)

        # Convertir columnas a los tipos de datos deseados
        df['cliente'] = df['cliente'].astype(str)
        df['medio'] = df['medio'].astype(str)
        df['anuncio'] = df['anuncio'].astype(str)  # Opcional, ya que está vacío
        df['fecha_cita'] = pd.to_datetime(df['fecha_cita'], format='%d/%m/%Y', errors='coerce')  # Convertir a fecha
        df['hora_cita'] = pd.to_datetime(df['hora_cita'], format='%H:%M', errors='coerce').dt.time()  # #REVISAR SI EL PARENTISIS NO CAUSA ERROR
        df['fraccionamiento'] = df['fraccionamiento'].astype(str)
        df['asesor'] = df['asesor'].astype(str)
        df['contacto_cliente'] = df['contacto_cliente'].astype(str)  # Mantener como texto para evitar problemas

        # Sobrescribir el archivo original con el DataFrame formateado
        df.to_csv(file_path, index=False)
        print(f"Archivo formateado y sobrescrito: {file_path}")

print("Proceso de cambio de tipos realizado.")
# Out:
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Abril_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Agosto_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasGral.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Diciembre_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Enero_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Febrero_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Julio_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Junio_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Marzo_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Mayo_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Noviembre_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Octubre_2024.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2023.csv
# Archivo formateado y sobrescrito: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Septiembre_2024.csv
# Proceso de cambio de tipos realizado.

# %% [markdown]
# ## combinar todos los archivos en uno solo

# %%
import pandas as pd
import os

# Ruta donde están los CSVs
folder_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/"

# Lista para almacenar los DataFrames
dataframes = []

# Iterar sobre los archivos en la carpeta
for file in os.listdir(folder_path):
    if file.endswith(".csv"):  # Verifica que sea un archivo CSV
        file_path = os.path.join(folder_path, file)
        
        # Leer el archivo CSV
        df = pd.read_csv(file_path)
        
        # Agregar el DataFrame a la lista
        dataframes.append(df)

# Combinar los DataFrames por columnas comunes
combined_df = pd.concat(dataframes, axis=0, join="inner", ignore_index=True)

# Guardar el DataFrame combinado en un nuevo archivo
output_path = os.path.join(folder_path, "Combined_Data.csv")
combined_df.to_csv(output_path, index=False)

print(f"Se han combinado todos los archivos en: {output_path}")
# Out:
# Se han combinado todos los archivos en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv

# %% [markdown]
# ## revisar que esten los registros de todos los archivos combinados

# %%
import pandas as pd

df=pd.read_csv("/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cliente</th><th>medio</th><th>anuncio</th><th>fecha_cita</th><th>hora_cita</th><th>fraccionamiento</th><th>asesor</th><th>contacto_cliente</th></tr></thead><tbody><tr><td>Anahí Carreón</td><td>facebook</td><td>null</td><td>2024-03-29</td><td>11:00:00</td><td>Altavista</td><td>Evelyn</td><td>8444990294</td></tr><tr><td>Oscar Leonardo Domínguez</td><td>pagina web</td><td>null</td><td>2024-03-31</td><td>12:00:00</td><td>Morillo</td><td>Elbia</td><td>8443490772</td></tr><tr><td>Jorge Antonio Carmona</td><td>whatsapp</td><td>null</td><td>2024-03-31</td><td>11:00:00</td><td>Bosques</td><td>Miguel</td><td>7224435137</td></tr><tr><td>Gabriela González</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>04:00:00</td><td>Altavista</td><td>Miguel</td><td>8441011388</td></tr><tr><td>Jose Negrete </td><td>facebook</td><td>null</td><td>2024-03-31</td><td>03:00:00</td><td>Altavista</td><td>Miguel</td><td>8441053934</td></tr><tr><td>Oscar Alan Piña</td><td>pagina web</td><td>null</td><td>2024-04-01</td><td>05:00:00</td><td>Morillo</td><td>Cesar</td><td>3411703104</td></tr><tr><td>Jonathan Jovany Garibay
path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv"

# Leer el archivo CSV
try:
    df = pd.read_csv(file_path)

    # Convertir todos los valores de las columnas 'medio' y 'asesor' a minúsculas
    df['medio'] = df['medio'].str.lower()
    df['asesor'] = df['asesor'].str.lower()
    df['fraccionamiento'] = df['fraccionamiento'].str.lower()

    # Sobrescribir el archivo original con los cambios
    df.to_csv(file_path, index=False)
    print(f"Valores de las columnas 'medio' y 'asesor' convertidos a minúsculas y guardados en: {file_path}")

except Exception as e:
    print(f"Error al procesar el archivo: {e}")

print("Cambio completado de contenido en columnas a minusculas.")
# Out:
# Valores de las columnas 'medio' y 'asesor' convertidos a minúsculas y guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv
# Cambio de contenido en columnas a minusculas en columnas completado.

# %% [markdown]
# ## Regularizacion de variables en columnas para facilitar el analisis (para informacion escrita de muchas formas con el mismo significado)

# %%
import pandas as pd

# Ruta al archivo CSV específico
file_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv"

# Leer el archivo CSV
try:
    df = pd.read_csv(file_path)

    # Reemplazar valores específicos en la columna 'medio'
    replacements = {
        r'\bface\b': 'facebook',  # Cambiar 'face' por 'facebook'
        r'\bpag\s*web\b': 'pagina web',  # Cambiar 'pag web' por 'pagina web'
        r'\bwhats\b': 'whatsapp'  # Cambiar 'whats' por 'whatsapp'
    }

    for pattern, replacement in replacements.items():
        df['medio'] = df['medio'].str.replace(pattern, replacement, case=False, regex=True)

    # Sobrescribir el archivo original con los cambios
    df.to_csv(file_path, index=False)
    print(f"Valores actualizados en la columna 'medio' y guardados en: {file_path}")
    print("Proceso de reemplazo con normalizacion completado.")

except Exception as e:
    print(f"Error al procesar el archivo: {e}")
# Out:
# Valores actualizados en la columna 'medio' y guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv
# Proceso de reemplazo con normalizacion completado.

# %%
import pandas as pd

df = pd.read_csv("/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cliente</th><th>medio</th><th>anuncio</th><th>fecha_cita</th><th>hora_cita</th><th>fraccionamiento</th><th>asesor</th><th>contacto_cliente</th></tr></thead><tbody><tr><td>Anahí Carreón</td><td>facebook</td><td>null</td><td>2024-03-29</td><td>11:00:00</td><td>altavista</td><td>evelyn</td><td>8444990294</td></tr><tr><td>Oscar Leonardo Domínguez</td><td>pagina web</td><td>null</td><td>2024-03-31</td><td>12:00:00</td><td>morillo</td><td>elbia</td><td>8443490772</td></tr><tr><td>Jorge Antonio Carmona</td><td>whatsapp</td><td>null</td><td>2024-03-31</td><td>11:00:00</td><td>bosques</td><td>miguel</td><td>7224435137</td></tr><tr><td>Gabriela González</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>04:00:00</td><td>altavista</td><td>miguel</td><td>8441011388</td></tr><tr><td>Jose Negrete </td><td>facebook</td><td>null</td><td>2024-03-31</td><td>03:00:00</td><td>altavista</td><td>miguel</td><td>8441053934</td></tr><tr><td>Oscar Alan Piña</td><td>pagina web</td><td>null</td><td>2024-04-01</td><td>05:00:00</td><td>morillo</td><td>cesar</td><td>3411703104</td></tr><tr><td>Jonathan Jovany Garibay Acevedo</td><td>pagina web</td><td>null</td><td>2024-04-01</td><td>11:00:00</td><td>altavista</td><td>evelyn</td><td>8444990294</td></tr><tr><td>Víctor
path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv"

# Leer el archivo CSV
df = pd.read_csv(file_path)

# Lista de columnas a procesar
columns_to_process = ['cliente', 'medio', 'anuncio', 'fraccionamiento', 'asesor']

# Limpiar espacios y reemplazar espacios entre palabras por guiones bajos
for column in columns_to_process:
    df[column] = df[column].apply(
        lambda x: '_'.join(x.strip().split()) if isinstance(x, str) else x
    )

# Guardar los cambios sobrescribiendo el archivo original
df.to_csv(file_path, index=False)

print(f"Archivo actualizado con espacios limpiados y reemplazados por guiones bajos: {file_path}")
# Out:
# Archivo actualizado con espacios limpiados y reemplazados por guiones bajos: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv

# %% [markdown]
# ## Opcional para mejorar el analisis
#
# import pandas as pd
#
# # Ruta al archivo CSV específico
# file_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/CitasCombinadas_Rename.csv"
#
# # Leer el archivo CSV
# try:
#     df = pd.read_csv(file_path)
#
#     # Contar las palabras en la columna 'fraccionamiento'
#     count_values = df['fraccionamiento'].value_counts()
#
#     # Mostrar los resultados
#     print("Conteo de valores en la columna 'medio':")
#     print(count_values)
#
#     # Opcional: Guardar el conteo en un archivo CSV
#     count_values.to_csv("/dbfs/mnt/GoogleSheets/CSV's_Descargados/Conteo_Medio.csv", header=["Conteo"])
#     print("Conteo guardado en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Conteo_Asesor.csv")
#
# except Exception as e:
#     print(f"Error al procesar el archivo: {e}")
#
# print("Proceso de conteo completado.")

# %% [markdown]
# ## limpieza de valores en columna para mejorar el analisis

# %%
import pandas as pd

# Ruta al archivo CSV específico
file_path = "/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv"

# Leer el archivo CSV
try:
    df = pd.read_csv(file_path)

    # Reemplazar los valores que contengan 'crisina' o 'cristi' con 'cristina' en la columna 'asesor'
    df['asesor'] = df['asesor'].str.replace(r'\b(crisina|cristi)\b', 'cristina', case=False, regex=True)

    # Sobrescribir el archivo original con los cambios
    df.to_csv(file_path, index=False)
    print(f"Valores actualizados en la columna 'asesor' y guardados en: {file_path}")
    print("Proceso de reemplazo completado.")

except Exception as e:
    print(f"Error al procesar el archivo: {e}")
# Out:
# Valores actualizados en la columna 'asesor' y guardados en: /dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv
# Proceso de reemplazo completado.

# %%
import pandas as pd

pd = pd.read_csv("/dbfs/mnt/GoogleSheets/CSV's_Descargados/Combined_Data.csv")

display(pd)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cliente</th><th>medio</th><th>anuncio</th><th>fecha_cita</th><th>hora_cita</th><th>fraccionamiento</th><th>asesor</th><th>contacto_cliente</th></tr></thead><tbody><tr><td>Anahí_Carreón</td><td>facebook</td><td>null</td><td>2024-03-29</td><td>11:00:00</td><td>altavista</td><td>evelyn</td><td>8444990294</td></tr><tr><td>Oscar_Leonardo_Domínguez</td><td>pagina_web</td><td>null</td><td>2024-03-31</td><td>12:00:00</td><td>morillo</td><td>elbia</td><td>8443490772</td></tr><tr><td>Jorge_Antonio_Carmona</td><td>whatsapp</td><td>null</td><td>2024-03-31</td><td>11:00:00</td><td>bosques</td><td>miguel</td><td>7224435137</td></tr><tr><td>Gabriela_González</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>04:00:00</td><td>altavista</td><td>miguel</td><td>8441011388</td></tr><tr><td>Jose_Negrete</td><td>facebook</td><td>null</td><td>2024-03-31</td><td>03:00:00</td><td>altavista</td><td>miguel</td><td>8441053934</td></tr><tr><td>Oscar_Alan_Piña</td><td>pagina_web</td><td>null</td><td>2024-04-01</td><td>05:00:00</td><td>morillo</td><td>cesar</td